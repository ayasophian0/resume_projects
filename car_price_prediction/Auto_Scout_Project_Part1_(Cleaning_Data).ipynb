# %% [markdown]
# # Car Price Prediction Project PART I

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import skimpy

import warnings 
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ### Reading and Understanding Data

# %%
## Reading Data

df0 = pd.read_json("as24_cars.json")
df = df0.copy()

# %%
df.sample(5)
# Out:
#                    make_model  \
# 1615   Mercedes-Benz C 43 AMG
# 28093              Volvo XC40
# 3129             Opel Cascada
# 17491             Toyota MR 2
# 19876             Nissan 370Z
#
#                                       short_description               make  \
# 1615     BREAK | PANO | DESIGNO | CARBON | CAMERA | LED  \nMercedes-Benz\n
# 28093  1.5 T3 Momentum/Geartronic/Navi/Leder/SafetyPack          \nVolvo\n
# 3129           Innovation ecoFlex Allu Tüv Garagenwagen           \nOpel\n
# 17491                                          Roadster         \nToyota\n
# 19876                                        370 Z Pack         \nNissan\n
#
#                     model                                        location  \
# 1615   [\n, C 43 AMG ,\n]  Peperstraat 50G,  9800 Bachte-Maria-Leerne, BE
# 28093      [\n, XC40 ,\n]      Luikersteenweg 320,  3800 Sint-Truiden, BE
# 3129    [\n, Cascada ,\n]        An Der Neuweide 32,  47495 Rheinberg, DE
# 17491      [\n, MR 2 ,\n]                   66780 Rehlingen Siersburg, DE
# 19876      [\n, 370Z ,\n]                               32758 Detmold, DE
#
#             price                   Body type            Type        Doors  \
# 1615   € 39,900.-     [\n, Station wagon, \n]  [\n, Used, \n]  [\n, 5, \n]
# 28093  € 33,900.-  [\n, Off-Road/Pick-up, \n]  [\n, Used, \n]  [\n, 5, \n]
# 3129   € 14,500.-       [\n, Convertible, \n]  [\n, Used, \n]  [\n, 2, \n]
# 17491  € 14,800.-       [\n, Convertible, \n]  [\n, Used, \n]  [\n, 2, \n]
# 19876  € 32,500.-             [\n, Coupe, \n]  [\n, Used, \n]  [\n, 2, \n]
#
#          Country version Offer number             Warranty    Mileage  \
# 1615   [\n, Belgium, \n]          NaN                  NaN  68,900 km
# 28093                NaN          NaN  [\n, 12 months, \n]  69,800 km
# 3129   [\n, Germany, \n]          NaN        [\n, Yes, \n]  80,000 km
# 17491                NaN          NaN                  NaN  66,000 km
# 19876                NaN          NaN                  NaN  11,800 km
#
#       First registration          Gearbox Fuel type Colour     Paint  \
# 1615             12/2016  [\nAutomatic\n]  Gasoline  Black       NaN
# 28093            07/2019  [\nAutomatic\n]  Gasoline   Grey       NaN
# 3129             04/2014     [\nManual\n]    Diesel    NaN  Metallic
# 17491            06/2000     [\nManual\n]  Gasoline    Red       NaN
# 19876            01/2019     [\nManual\n]  Gasoline  White  Metallic
#
#                                                     desc          seller  \
# 1615   [Zwart metallic exterieur, Designo bruin volle...          Dealer
# 28093  [Groot onderhoud & nazicht., Professionele rei...          Dealer
# 3129   [Sonderausstattung:,  Assistenz-Paket, Audio-N...          Dealer
# 17491                                                NaN  Private seller
# 19876  [370 Z, Weiß , ca. 340 PS, AGA Invidia Gemini,...  Private seller
#
#              Seats                  Power     Engine size    Gears  \
# 1615   [\n, 5, \n]  [\n270 kW (367 hp)\n]  [\n2,998 cc\n]  [\n8\n]
# 28093  [\n, 5, \n]  [\n120 kW (163 hp)\n]  [\n1,477 cc\n]  [\n8\n]
# 3129   [\n, 4, \n]  [\n121 kW (165 hp)\n]  [\n1,956 cc\n]      NaN
# 17491  [\n, 2, \n]  [\n103 kW (140 hp)\n]  [\n1,794 cc\n]  [\n5\n]
# 19876  [\n, 2, \n]  [\n241 kW (328 hp)\n]  [\n3,696 cc\n]  [\n6\n]
#
#           CO₂-emissions             Manufacturer colour       Drivetrain  \
# 1615   185 g/km (comb.)                             NaN    [\n, 4WD, \n]
# 28093  147 g/km (comb.)                             NaN  [\n, Front, \n]
# 3129   138 g/km (comb.)  Karbonschw GraphitSchw Midnigh              NaN
# 17491  178 g/km (comb.)                             NaN              NaN
# 19876  248 g/km (comb.)                             NaN   [\n, Rear, \n]
#
#       Cylinders                                   Fuel consumption  \
# 1615    [\n6\n]  [[6 l/100 km (comb.)], [6 l/100 km (city)], [6...
# 28093   [\n3\n]  [[6.5 l/100 km (comb.)], [8.3 l/100 km (city)]...
# 3129        NaN  [[5.2 l/100 km (comb.)], [6.3 l/100 km (city)]...
# 17491   [\n4\n]  [[7.4 l/100 km (comb.)], [10.1 l/100 km (city)...
# 19876   [\n6\n]  [[10.6 l/100 km (comb.)], [15.4 l/100 km (city...
#
#                                \nComfort & Convenience\n  \
# 1615   [Air conditioning, Armrest, Automatic climate ...
# 28093  [360° camera, Air conditioning, Armrest, Autom...
# 3129   [Air conditioning, Armrest, Automatic climate ...
# 17491  [Electrical side mirrors, Leather steering whe...
# 19876  [Air conditioning, Automatic climate control, ...
#
#                                \nEntertainment & Media\n  \
# 1615   [Bluetooth, CD player, Digital radio, Hands-fr...
# 28093  [Bluetooth, On-board computer, Radio, Sound sy...
# 3129   [Bluetooth, CD player, Integrated music stream...
# 17491                                [On-board computer]
# 19876  [Bluetooth, CD player, Hands-free equipment, O...
#
#                                    \nSafety & Security\n  \
# 1615   [ABS, Adaptive headlights, Alarm system, Bi-Xe...
# 28093  [ABS, Adaptive Cruise Control, Blind spot moni...
# 3129   [ABS, Central door lock, Daytime running light...
# 17491  [ABS, Central door lock with remote control, D...
# 19876  [ABS, Alarm system, Daytime running lights, Dr...
#
#                                               \nExtras\n    Empty weight  \
# 1615   [Alloy wheels, Ambient lighting, Automatically...             NaN
# 28093  [Alloy wheels, Automatically dimming interior ...  [\n1,625 kg\n]
# 3129   [All season tyres, Alloy wheels, Smoker's pack...             NaN
# 17491                        [Alloy wheels, Sport seats]  [\n1,050 kg\n]
# 19876  [Alloy wheels, Headlight washer system, Spoile...  [\n1,571 kg\n]
#
#       Model code General inspection Last service Full service history  \
# 1615         NaN                NaN          NaN                  Yes
# 28093        NaN                NaN          NaN                  NaN
# 3129         NaN            04/2023          NaN                  Yes
# 17491        NaN                NaN          NaN                  Yes
# 19876        NaN            03/2024          NaN                  NaN
#
#       Non-smoker vehicle Emission class Emissions sticker Upholstery colour  \
# 1615                 Yes         Euro 6               NaN             Brown
# 28093                NaN        Euro 6d               NaN             Beige
# 3129                 Yes         Euro 5         4 (Green)             Brown
# 17491                Yes            NaN               NaN               NaN
# 19876                Yes   Euro 6d-TEMP         4 (Green)             Black
#
#          Upholstery  Production date             Previous owner  \
# 1615   Full leather              NaN  [[68,900 km, 12/2016], 1]
# 28093  Full leather              NaN                        NaN
# 3129   Full leather              NaN  [[80,000 km, 04/2014], 2]
# 17491           NaN              NaN  [[66,000 km, 06/2000], 1]
# 19876  Part leather              NaN  [[11,800 km, 01/2019], 1]
#
#       Other fuel types Power consumption Energy efficiency class  \
# 1615               NaN               NaN                     NaN
# 28093              NaN               NaN                     NaN
# 3129               NaN               NaN                     NaN
# 17491              NaN               NaN                     NaN
# 19876              NaN               NaN                     NaN
#
#       CO₂-efficiency Fuel consumption (WLTP) CO₂-emissions (WLTP)  \
# 1615             NaN                     NaN                  NaN
# 28093            NaN                     NaN                  NaN
# 3129             NaN                     NaN                  NaN
# 17491            NaN                     NaN                  NaN
# 19876            NaN                     NaN                  NaN
#
#       Available from Taxi or rental car Availability Last timing belt change  \
# 1615             NaN                NaN          NaN                     NaN
# 28093            NaN                NaN          NaN                     NaN
# 3129             NaN                NaN          NaN                     NaN
# 17491            NaN                NaN          NaN                     NaN
# 19876            NaN                NaN          NaN                     NaN
#
#       Electric Range (WLTP) Power consumption (WLTP) Battery Ownership
# 1615                    NaN                      NaN               NaN
# 28093                   NaN                      NaN               NaN
# 3129                    NaN                      NaN               NaN
# 17491                   NaN                      NaN               NaN
# 19876                   NaN                      NaN               NaN

# %%
df.isnull().sum() / len(df) * 100
# Out:
# make_model                    2.883311
# short_description             2.883311
# make                          2.883311
# model                         2.883311
# location                      2.883311
# price                         2.883311
# Body type                     2.883311
# Type                          2.883311
# Doors                         4.101085
# Country version              42.710312
# Offer number                 21.641791
# Warranty                     46.458616
# Mileage                       2.886703
# First registration            2.890095
# Gearbox                       3.724559
# Fuel type                     8.945047
# Colour                        8.731343
# Paint                        50.831072
# desc                          4.860923
# seller                        2.883311
# Seats                        13.483718
# Power                         4.823609
# Engine size                   7.642469
# Gears                        35.705563
# CO₂-emissions                36.926730
# Manufacturer colour          26.095658
# Drivetrain                   42.696744
# Cylinders                    36.051560
# Fuel consumption             20.675034
# \nComfort & Convenience\n    13.727951
# \nEntertainment & Media\n    19.796472
# \nSafety & Security\n        13.789009
# \nExtras\n                   20.352782
# Empty weight                 39.762551
# Model code                   71.618046
# General inspection           58.432836
# Last service                 93.205563
# Full service history         57.377883
# Non-smoker vehicle           60.671642
# Emission class               39.419946
# Emissions sticker            68.066486
# Upholstery colour            50.580054
# Upholstery                   36.872456
# Production date              79.959294
# Previous owner               52.459294
# Other fuel types             92.154003
# Power consumption            98.253053
# Energy efficiency class      73.527815
# CO₂-efficiency               73.527815
# Fuel consumption (WLTP)      99.660787
# CO₂-emissions (WLTP)         99.606513
# Available from               98.666893
# Taxi or rental car           98.568521
# Availability                 98.978969
# Last timing belt change      98.059701
# Electric Range (WLTP)        99.945726
# Power consumption (WLTP)     99.945726
# Battery Ownership            99.976255
# dtype: float64

# %%
df.columns = skimpy.clean_columns(df).columns

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'body_type', 'type', 'doors', 'country_version', 'offer_number',
#        'warranty', 'mileage', 'first_registration', 'gearbox', 'fuel_type',
#        'colour', 'paint', 'desc', 'seller', 'seats', 'power', 'engine_size',
#        'gears', 'co_emissions', 'manufacturer_colour', 'drivetrain',
#        'cylinders', 'fuel_consumption', 'comfort_&_convenience',
#        'entertainment_&_media', 'safety_&_security', 'extras', 'empty_weight',
#        'model_code', 'general_inspection', 'last_service',
#        'full_service_history', 'non_smoker_vehicle', 'emission_class',
#        'emissions_sticker', 'upholstery_colour', 'upholstery',
#        'production_date', 'previous_owner', 'other_fuel_types',
#        'power_consumption', 'energy_efficiency_class', 'co_efficiency',
#        'fuel_consumption_wltp', 'co_emissions_wltp', 'available_from',
#        'taxi_or_rental_car', 'availability', 'last_timing_belt_change',
#        'electric_range_wltp', 'power_consumption_wltp', 'battery_ownership'],
#       dtype='object')

# %% [markdown]
# ### Cleaning columns

# %%
df.make = df.make.str.strip('\n')

# %%
df.make.head()
# Out:
# 0    Mercedes-Benz
# 1    Mercedes-Benz
# 2    Mercedes-Benz
# 3    Mercedes-Benz
# 4    Mercedes-Benz
# Name: make, dtype: object

# %%
df.model = df.model.map(lambda x: ",".join(x) if type(x) == list else x).str.strip('\n, ')

# %%
df.model.head()
# Out:
# 0       A 160
# 1     EQE 350
# 2    A 45 AMG
# 3    A 35 AMG
# 4    A 45 AMG
# Name: model, dtype: object

# %%
df.loc[df[(df.model == '') & (df.make == 'Opel')].index, 'model'] = 'Excellence'

# %%
df.loc[3367, 'model'] = 'Olympia'
df.loc[3387, 'model'] = 'Astra'

# %%
df[(df.model == '')].shape
# Out:
# (173, 58)

# %%
df.price = df.price.str.strip('€.-').str.replace(',', '').astype('float')

# %%
df.price.head()
# Out:
# 0    16950.0
# 1    80900.0
# 2    69900.0
# 3    46990.0
# 4    16800.0
# Name: price, dtype: float64

# %%
df.body_type = df.body_type.map(lambda x: ",".join(x) if type(x) == list else x).str.strip('\n, ').str.replace(',','')

# %%
df.body_type.head()
# Out:
# 0    Compact
# 1    Compact
# 2    Compact
# 3    Compact
# 4    Compact
# Name: body_type, dtype: object

# %%
df.type = df.type.map(lambda x: ",".join(x) if type(x) == list else x).str.strip('\n, ').str.replace(',','')

# %%
df.type.head()
# Out:
# 0              Used
# 1    Pre-registered
# 2              Used
# 3              Used
# 4              Used
# Name: type, dtype: object

# %%
df.doors = df.doors.map(lambda x: ",".join(x) if type(x) == list else x).str.strip('\n, ').str.replace(',','').astype('float')

# %%
df.doors.head()
# Out:
# 0    5.0
# 1    4.0
# 2    5.0
# 3    5.0
# 4    5.0
# Name: doors, dtype: float64

# %%
df.country_version = df.country_version.map(lambda x: ",".join(x) if type(x) == list else x).str.strip('\n, ').str.replace(',','')

# %%
df.country_version.head()
# Out:
# 0    Spain
# 1    Spain
# 2    Spain
# 3    Spain
# 4    Spain
# Name: country_version, dtype: object

# %%
df.offer_number = df.offer_number.map(lambda x: ",".join(x) if type(x) == list else x).str.strip('\n, ').str.replace(',','')

# %%
df.offer_number.head()
# Out:
# 0    7468157
# 1    7054863
# 2    7410454
# 3    7464503
# 4    7127931
# Name: offer_number, dtype: object

# %%
df.warranty = df.warranty.map(lambda x: ",".join(x) if type(x) == list else x).str.strip('\n, ').str.replace(',','')

# %%
df.warranty.head()
# Out:
# 0    24 months
# 1    24 months
# 2    12 months
# 3    12 months
# 4    12 months
# Name: warranty, dtype: object

# %%
df.mileage = df.mileage.str.split(" ").map(lambda x: x[0] if type(x) == list else x).str.replace(',', '').astype('float')

# %%
df["age"] = 2022 - df.first_registration.str.split('/').map(lambda x: x[1] if type(x) == list else x).astype('float')

# %%
df.age.head()
# Out:
# 0    6.0
# 1    0.0
# 2    2.0
# 3    2.0
# 4    7.0
# Name: age, dtype: float64

# %%
df.gearbox = df.gearbox.map(lambda x: ",".join(x) if type(x) == list else x).str.strip('\n, ')

# %%
df.gearbox.head()
# Out:
# 0       Manual
# 1    Automatic
# 2    Automatic
# 3    Automatic
# 4    Automatic
# Name: gearbox, dtype: object

# %%
df.desc = df.desc.map(lambda x: ",".join(x) if type(x) == list else x)

# %%
df.desc.head()
# Out:
# 0     ,Precio al contado: 16950 euros, , ,Vehículo ...
# 1     ,Precio al contado: 88900 euros, ,AUTO OJA S....
# 2    Gris MANUFAKTUR mountaingrau magno, ,Linea/Est...
# 3     ,Precio al contado: 48990 euros, , ,BONIFICAC...
# 4     ,Precio al contado: 17400 euros, ,Vehículo en...
# Name: desc, dtype: object

# %%
df.seats = df.seats.map(lambda x: ",".join(x) if type(x) == list else x).str.strip('\n, ').str.replace(',','')

# %%
df.seats = df.seats.astype('float')

# %%
df.seats.head()
# Out:
# 0    NaN
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# Name: seats, dtype: float64

# %%
df['power_kW'] = df.power.map(lambda x: ",".join(x) if type(x) == list else x).str.extract('(\d+) kW').astype('float')

# %%
df.power_kW.head()
# Out:
# 0      NaN
# 1    215.0
# 2    310.0
# 3    225.0
# 4    100.0
# Name: power_kW, dtype: float64

# %%
df['horse_power'] = df.power.map(lambda x: ",".join(x) if type(x) == list else x).str.extract('\((\d+) hp\)').astype('float')

# %%
df.horse_power.head()
# Out:
# 0      NaN
# 1    292.0
# 2    421.0
# 3    306.0
# 4    136.0
# Name: horse_power, dtype: float64

# %%
df.engine_size = (df.engine_size.map(lambda x: x[0].strip("\n c").replace(",", "") if type(x) == list else x).astype(float) / 1000)\
        .astype(str).str.extract("(\d+\.*\d)").astype(float)

# %%
df.engine_size.head()
# Out:
# 0    NaN
# 1    0.0
# 2    1.9
# 3    1.9
# 4    2.1
# Name: engine_size, dtype: float64

# %%
df.gears = df.gears.map(lambda x: ",".join(x) if type(x) == list else x).str.strip('\n, ')

# %%
df.gears = df.gears.astype('float')

# %%
df.gears.head()
# Out:
# 0    NaN
# 1    9.0
# 2    8.0
# 3    7.0
# 4    7.0
# Name: gears, dtype: float64

# %%
df.co_emissions = df0["CO₂-emissions"].str.extract('(\d+) ').astype('float')

# %%
df.co_emissions.sample(5)
# Out:
# 24897    173.0
# 14895    116.0
# 28368    176.0
# 18323      NaN
# 6318     130.0
# Name: co_emissions, dtype: float64

# %%
df.manufacturer_colour = df.manufacturer_colour.str.title().str.strip(' ')

# %%
df.manufacturer_colour.head()
# Out:
# 0                   NaN
# 1       Negro Obsidiana
# 2    Mountaingrau Magno
# 3          Amarillo Sol
# 4                   NaN
# Name: manufacturer_colour, dtype: object

# %%
df.drivetrain = df.drivetrain.map(lambda x: ",".join(x) if type(x) == list else x).str.strip('\n, ').str.replace(',', '')

# %%
df.drivetrain.head()
# Out:
# 0    NaN
# 1    NaN
# 2    4WD
# 3    4WD
# 4    4WD
# Name: drivetrain, dtype: object

# %%
df.cylinders = df.cylinders.map(lambda x: ",".join(x) if type(x) == list else x).str.strip('\n, ').astype('float')

# %%
df.cylinders.head()
# Out:
# 0    NaN
# 1    NaN
# 2    4.0
# 3    4.0
# 4    4.0
# Name: cylinders, dtype: float64

# %%
import itertools

df["f_consumption_per_100_combined"] = df.fuel_consumption.map(lambda x: ",".join(list(itertools.chain.from_iterable(x))) if type(x) == list else x)\
            .str.extract('(.+) l/100 km \(comb.\)').astype('float')

# %%
def standardize(value):
    if value == np.nan:
        return np.nan
    if value <= 10:
        return 'Standard'
    if value > 10 and value <= 20:
        return 'Premium'
    if value > 20:
        return 'Deluxe'

df["comfort_&_convenience"] = df["comfort_&_convenience"].map(lambda x: ''.join(x) if type(x) == list else x)

df["comfort_convenience_pack"] = df["comfort_&_convenience"].map(lambda x: ''.join(x) if type(x) == list else x)\
        .map(lambda x: x.split(',') if type(x) == str else x)\
        .map(lambda x: len(x) if type(x) == list else x).map(lambda x: standardize(x) if type(x) == float else x)

# %%
def standardize_2(value):
    if value == np.nan:
        return np.nan
    if value <= 12:
        return 'Standard'
    if value > 12 and value <= 24:
        return 'Premium'
    if value > 24:
        return 'Deluxe'

df['safety_&_security'] = df['safety_&_security'].map(lambda x: ''.join(x) if type(x) == list else x)

df['safety_security_pack'] = df['safety_&_security'].map(lambda x: ''.join(x) if type(x) == list else x)\
        .map(lambda x: x.split(',') if type(x) == str else x)\
        .map(lambda x: len(x) if type(x) == list else x).map(lambda x: standardize_2(x) if type(x) == float else x)

# %%
def standardize_3(value):
    if value == np.nan:
        return np.nan
    if value <= 6:
        return 'Standard'
    if value > 6 and value <= 12:
        return 'Premium'
    if value > 12:
        return 'Deluxe'

df['entertainment_&_media'] = df['entertainment_&_media'].map(lambda x: ''.join(x) if type(x) == list else x)

df['entertainment_pack'] = df['entertainment_&_media'].map(lambda x: ''.join(x) if type(x) == list else x)\
        .map(lambda x: x.split(',') if type(x) == str else x)\
        .map(lambda x: len(x) if type(x) == list else x).map(lambda x: standardize_3(x) if type(x) == float else x)

# %%
def standardize_4(value):
    if value == np.nan:
        return np.nan
    if value <= 9:
        return 'Standard'
    if value > 9 and value <= 18:
        return 'Premium'
    if value > 18:
        return 'Deluxe'

df.extras = df.extras.map(lambda x: ''.join(x) if type(x) == list else x)

df['extra_pack'] = df.extras.map(lambda x: ''.join(x) if type(x) == list else x)\
        .map(lambda x: x.split(',') if type(x) == str else x)\
        .map(lambda x: len(x) if type(x) == list else x).map(lambda x: standardize_4(x) if type(x) == float else x)

# %%
df.empty_weight = df.empty_weight.map(lambda x: ''.join(x) if type(x) == list else x).str.strip('\nkg ')\
            .str.replace(',','').astype('float')

# %%
df.model_code = df.model_code.map(lambda x: ''.join(x) if type(x) == list else x).str.strip('\n, ')

# %%
df.model_code.sample(5)
# Out:
# 19836    NaN
# 1976     NaN
# 5891     NaN
# 13806    NaN
# 26279    NaN
# Name: model_code, dtype: object

# %%
df.upholstery = df.upholstery.str.title().str.strip(' ')

# %%
df.upholstery.sample(5)
# Out:
# 17688             NaN
# 13228           Cloth
# 17053             NaN
# 12960       Alcantara
# 4030     Full Leather
# Name: upholstery, dtype: object

# %%
df.previous_owner = df.previous_owner.map(lambda x: x[1] if type(x) == list else x).astype('float')

# %%
df.power_consumption = df.power_consumption.str.extract('(\d+|\d+.\d+) ').astype('float')

# %%
df.power_consumption.sample(5)
# Out:
# 1102    NaN
# 11249   NaN
# 28210   NaN
# 9122    NaN
# 4511    NaN
# Name: power_consumption, dtype: float64

# %% [markdown]
# ### Dropping columns

# %%
df.sample(10)
# Out:
#            make_model                                 short_description  \
# 8814      Peugeot 308       SW Business-Line # Navi # Sitzheizung # USB
# 26819       Volvo C70                              Cabrio 2.5 T / 2.4 T
# 27405       Volvo C30                               D2 Edition R-Design
# 21077     Nissan Leaf  Tekna 40 kWh ab 20.000, Winterreifen, Bestausst.
# 2974            Opel                         Cabrio 1.4T S&S Excellence
# 21866   Ford Streetka           Roadster 1.6 TÜV NEU 2. JAHRE SCHECKHEF
# 24348     Hyundai i30      FL Fastback 1.5 Prime Sitzpaket Panoramadach
# 19723     Nissan 370Z                                 3.7 V6 328ch Pack
# 15210     Skoda Karoq                             4x4 Style Limited TDI
# 5025   Renault Megane                       1.6 TCe 205ch energy GT EDC
#
#           make       model                                           location  \
# 8814   Peugeot         308     Martin-Luther-Str. 37,  15517 Fürstenwalde, DE
# 26819    Volvo         C70             CALLE CATALUNYA, 37,  8520 LLERONA, ES
# 27405    Volvo         C30  Am Knipprather Busch 2 (Ecke Sandstr. 126),  4...
# 21077   Nissan        Leaf                  Saggrabenweg 3,  5422 Hallein, AT
# 2974      Opel  Excellence   CTRA. DE CAMION, KM. 311,  13005 CIUDAD REAL, ES
# 21866     Ford    Streetka  Mühlheimer Straße 315,  63075 Offenbach am Mai...
# 24348  Hyundai         i30                 Dürener Str. 35,  52428 Jülich, DE
# 19723   Nissan        370Z              52 avenue Eisenhower,  39100 DOLE, FR
# 15210    Skoda       Karoq               Gewerbepark 12,  4100 Ottensheim, AT
# 5025   Renault      Megane  81 avenue du Général de Gaulle,  68330 Saint L...
#
#          price      body_type           type  doors country_version  \
# 8814   11970.0  Station wagon           Used    5.0         Germany
# 26819   5199.0    Convertible           Used    2.0           Spain
# 27405   8950.0          Coupe           Used    2.0         Germany
# 21077  24000.0          Sedan           Used    5.0             NaN
# 2974   15421.0    Convertible           Used    2.0           Spain
# 21866   2500.0    Convertible           Used    2.0         Germany
# 24348  28480.0          Coupe  Demonstration    5.0         Germany
# 19723  22990.0    Convertible           Used    2.0             NaN
# 15210  27900.0          Sedan           Used    5.0             NaN
# 5025   21999.0        Compact           Used    5.0             NaN
#
#       offer_number   warranty   mileage first_registration    gearbox  \
# 8814        269161        NaN  126570.0            03/2015  Automatic
# 26819      7169262        NaN  156700.0            06/2001     Manual
# 27405          NaN        Yes  107458.0            03/2012     Manual
# 21077          NaN  24 months   57095.0            07/2018  Automatic
# 2974       7410282  12 months   62703.0            03/2015     Manual
# 21866          NaN        Yes   97000.0            04/2005     Manual
# 24348      J110558        Yes     100.0            08/2022     Manual
# 19723      FM12109        NaN  118034.0            06/2010     Manual
# 15210    360-18060        NaN   77500.0            05/2019     Manual
# 5025        211043   6 months   35477.0            08/2016        NaN
#
#                       fuel_type colour     paint  \
# 8814   Diesel (Particle filter)   Grey  Metallic
# 26819                  Gasoline   Blue       NaN
# 27405                    Diesel   Grey  Metallic
# 21077                       NaN  White       NaN
# 2974                   Gasoline    Red       NaN
# 21866        Regular/Benzine 91    Red       NaN
# 24348                  Super 95  Black  Metallic
# 19723                  Gasoline    NaN  Metallic
# 15210                    Diesel   Grey       NaN
# 5025                   Gasoline    NaN       NaN
#
#                                                     desc  seller  seats  \
# 8814   Sonstiges,Einparkhilfe akustisch,Einparkhilfe ...  Dealer    5.0
# 26819  %BACK TO SCHOOL%,Volvemos al trabajo, volvemos...  Dealer    4.0
# 27405  Voll-Lederausstattung,,Leichtmetallfelgen"17,,...  Dealer    4.0
# 21077  Nissan Leaf 40 kWh,Erstzulassung: 26.07.2018,-...  Dealer    5.0
# 2974    ,Precio al contado: 16500 euros, ,Ref.  9231J...  Dealer    4.0
# 21866  FORD STREETKA CABRIO 1.6 BENZIN,ORIGINAL 97.00...  Dealer    2.0
# 24348  Getriebe,Schaltgetriebe, 6 Gänge,Assistenzsyst...  Dealer    5.0
# 19723  Peinture métal;ABS;Aide au freinage d'urgence;...  Dealer    2.0
# 15210                                                NaN  Dealer    5.0
# 5025   Sellerie alcantara GT bleue et noire;similaire...  Dealer    5.0
#
#                        power  engine_size  gears  co_emissions  \
# 8814   [\n110 kW (150 hp)\n]          1.9    6.0         105.0
# 26819  [\n143 kW (194 hp)\n]          2.4    5.0           NaN
# 27405   [\n84 kW (114 hp)\n]          1.5    NaN         114.0
# 21077  [\n110 kW (150 hp)\n]          NaN    NaN           NaN
# 2974   [\n103 kW (140 hp)\n]          1.3    6.0           NaN
# 21866    [\n70 kW (95 hp)\n]          1.5    NaN         187.0
# 24348  [\n117 kW (159 hp)\n]          1.5    6.0         124.0
# 19723  [\n245 kW (333 hp)\n]          3.6    NaN         262.0
# 15210  [\n110 kW (150 hp)\n]          1.9    NaN         134.0
# 5025   [\n153 kW (208 hp)\n]          1.6    NaN         134.0
#
#               manufacturer_colour drivetrain  cylinders  \
# 8814                 Grau Artense        NaN        NaN
# 26819                        Azul      Front        5.0
# 27405    Titanium Grey / Metallic        NaN        NaN
# 21077  Perlmuttweiß - Permuttlack      Front        NaN
# 2974                         Rojo      Front        4.0
# 21866                   Rosso-Rot        NaN        NaN
# 24348               Phantom Black      Front        4.0
# 19723                       Blanc        NaN        NaN
# 15210                         NaN        4WD        NaN
# 5025                        Blanc        NaN        NaN
#
#                                         fuel_consumption  \
# 8814   [[4.2 l/100 km (comb.)], [4.9 l/100 km (city)]...
# 26819  [[9.8 l/100 km (comb.)], [13.6 l/100 km (city)...
# 27405  [[4.3 l/100 km (comb.)], [5.2 l/100 km (city)]...
# 21077                                                NaN
# 2974   [[6.3 l/100 km (comb.)], [7.8 l/100 km (city)]...
# 21866  [[7.9 l/100 km (comb.)], [10.6 l/100 km (city)...
# 24348  [[5.4 l/100 km (comb.)], [6.2 l/100 km (city)]...
# 19723                                                NaN
# 15210                           [[5.1 l/100 km (comb.)]]
# 5025                                                 NaN
#
#                                    comfort_&_convenience  \
# 8814   Air conditioning, Armrest, Automatic climate c...
# 26819  Air conditioning, Automatic climate control, E...
# 27405  Air conditioning, Armrest, Automatic climate c...
# 21077  360° camera, Air conditioning, Automatic clima...
# 2974   Air conditioning, Automatic climate control, C...
# 21866  Electrical side mirrors, Leather steering whee...
# 24348  Air conditioning, Armrest, Automatic climate c...
# 19723  Air conditioning, Automatic climate control, C...
# 15210  Air conditioning, Armrest, Automatic climate c...
# 5025   Armrest, Automatic climate control, 2 zones, H...
#
#                                    entertainment_&_media  \
# 8814   Bluetooth, CD player, Digital cockpit, Hands-f...
# 26819                                  On-board computer
# 27405  Bluetooth, CD player, Hands-free equipment, On...
# 21077  Android Auto, Apple CarPlay, Bluetooth, Digita...
# 2974        Bluetooth, CD player, MP3, On-board computer
# 21866                                   CD player, Radio
# 24348  Bluetooth, Hands-free equipment, MP3, On-board...
# 19723  Hands-free equipment, On-board computer, Sound...
# 15210  Hands-free equipment, MP3, On-board computer, ...
# 5025                                                 NaN
#
#                                        safety_&_security  \
# 8814   ABS, Central door lock, Daytime running lights...
# 26819  ABS, Central door lock, Driver-side airbag, Fo...
# 27405  ABS, Adaptive headlights, Bi-Xenon headlights,...
# 21077  ABS, Adaptive Cruise Control, Adaptive headlig...
# 2974   ABS, Central door lock, Driver-side airbag, El...
# 21866  ABS, Central door lock, Driver-side airbag, Fo...
# 24348  ABS, Alarm system, Central door lock, Central ...
# 19723  ABS, Central door lock, Driver-side airbag, El...
# 15210  ABS, Central door lock with remote control, Dr...
# 5025   ABS, Driver-side airbag, Emergency brake assis...
#
#                                                   extras  empty_weight  \
# 8814   Alloy wheels, Automatically dimming interior m...        1550.0
# 26819                                       Alloy wheels        1565.0
# 27405  Alloy wheels, Automatically dimming interior m...           NaN
# 21077  Alloy wheels (17"), Automatically dimming inte...           NaN
# 2974                                        Alloy wheels        1701.0
# 21866        All season tyres, Alloy wheels, Sport seats           NaN
# 24348                        Alloy wheels, Voice Control        1488.0
# 19723                                       Alloy wheels           NaN
# 15210                        Alloy wheels, Trailer hitch        1572.0
# 5025                        Sport package, Voice Control           NaN
#
#       model_code general_inspection last_service full_service_history  \
# 8814    3003/ATT            11/2022          NaN                  NaN
# 26819        NaN                NaN          NaN                  NaN
# 27405        NaN                New          NaN                  Yes
# 21077        NaN                NaN          NaN                  NaN
# 2974         NaN                NaN          NaN                  NaN
# 21866        NaN                New          NaN                  Yes
# 24348        NaN            08/2025          NaN                  NaN
# 19723        NaN                NaN          NaN                  NaN
# 15210        NaN                NaN          NaN                  Yes
# 5025         NaN                NaN          NaN                  NaN
#
#       non_smoker_vehicle emission_class emissions_sticker upholstery_colour  \
# 8814                 Yes         Euro 6         4 (Green)             Black
# 26819                NaN            NaN               NaN               NaN
# 27405                Yes         Euro 4         4 (Green)             Black
# 21077                Yes   Euro 6d-TEMP               NaN             Black
# 2974                 NaN            NaN               NaN               NaN
# 21866                NaN         Euro 4         4 (Green)             Black
# 24348                NaN   Euro 6d-TEMP               NaN             Black
# 19723                NaN            NaN               NaN               NaN
# 15210                NaN            NaN               NaN               NaN
# 5025                 NaN            NaN               NaN               NaN
#
#          upholstery  production_date  previous_owner other_fuel_types  \
# 8814          Other           2015.0             2.0              NaN
# 26819           NaN              NaN             NaN              NaN
# 27405  Full Leather              NaN             3.0              NaN
# 21077  Full Leather              NaN             1.0      Electricity
# 2974            NaN              NaN             NaN              NaN
# 21866         Cloth              NaN             2.0              NaN
# 24348  Full Leather           2022.0             1.0              NaN
# 19723  Full Leather              NaN             NaN              NaN
# 15210           NaN           2019.0             NaN              NaN
# 5025      Alcantara              NaN             NaN              NaN
#
#        power_consumption energy_efficiency_class  \
# 8814                 NaN                     NaN
# 26819                NaN                     NaN
# 27405                NaN                     NaN
# 21077                NaN                     NaN
# 2974                 NaN                     NaN
# 21866                NaN                     NaN
# 24348                NaN                       B
# 19723                NaN                     NaN
# 15210                NaN                     NaN
# 5025                 NaN                     NaN
#
#                                            co_efficiency  \
# 8814                                                 NaN
# 26819                                                NaN
# 27405                                                NaN
# 21077                                                NaN
# 2974                                                 NaN
# 21866                                                NaN
# 24348  Calculated on basis of measured CO₂-emissions ...
# 19723                                                NaN
# 15210                                                NaN
# 5025                                                 NaN
#
#       fuel_consumption_wltp co_emissions_wltp available_from  \
# 8814                    NaN               NaN            NaN
# 26819                   NaN               NaN            NaN
# 27405                   NaN               NaN            NaN
# 21077                   NaN    0 g/km (comb.)            NaN
# 2974                    NaN               NaN            NaN
# 21866                   NaN               NaN            NaN
# 24348                   NaN               NaN            NaN
# 19723                   NaN               NaN            NaN
# 15210                   NaN               NaN            NaN
# 5025                    NaN               NaN            NaN
#
#       taxi_or_rental_car availability last_timing_belt_change  \
# 8814                 NaN          NaN                     NaN
# 26819                NaN          NaN                     NaN
# 27405                NaN          NaN                     NaN
# 21077                NaN          NaN                     NaN
# 2974                 NaN          NaN                     NaN
# 21866                NaN          NaN                     NaN
# 24348                NaN          NaN                     NaN
# 19723                NaN          NaN                     NaN
# 15210                NaN          NaN                     NaN
# 5025                 NaN          NaN                     NaN
#
#       electric_range_wltp power_consumption_wltp battery_ownership   age  \
# 8814                  NaN                    NaN               NaN   7.0
# 26819                 NaN                    NaN               NaN  21.0
# 27405                 NaN                    NaN               NaN  10.0
# 21077              389 km        20.6 kWh/100 km          Included   4.0
# 2974                  NaN                    NaN               NaN   7.0
# 21866                 NaN                    NaN               NaN  17.0
# 24348                 NaN                    NaN               NaN   0.0
# 19723                 NaN                    NaN               NaN  12.0
# 15210                 NaN                    NaN               NaN   3.0
# 5025                  NaN                    NaN               NaN   6.0
#
#        power_kW  horse_power  f_consumption_per_100_combined  \
# 8814      110.0        150.0                             4.2
# 26819     143.0        194.0                             9.8
# 27405      84.0        114.0                             4.3
# 21077     110.0        150.0                             NaN
# 2974      103.0        140.0                             6.3
# 21866      70.0         95.0                             7.9
# 24348     117.0        159.0                             5.4
# 19723     245.0        333.0                             NaN
# 15210     110.0        150.0                             5.1
# 5025      153.0        208.0                             NaN
#
#       comfort_convenience_pack safety_security_pack entertainment_pack  \
# 8814                   Premium              Premium            Premium
# 26819                 Standard             Standard           Standard
# 27405                  Premium              Premium           Standard
# 21077                   Deluxe              Premium            Premium
# 2974                  Standard             Standard           Standard
# 21866                 Standard             Standard           Standard
# 24348                   Deluxe              Premium           Standard
# 19723                  Premium             Standard           Standard
# 15210                  Premium             Standard           Standard
# 5025                  Standard             Standard               None
#
#       extra_pack
# 8814    Standard
# 26819   Standard
# 27405   Standard
# 21077   Standard
# 2974    Standard
# 21866   Standard
# 24348   Standard
# 19723   Standard
# 15210   Standard
# 5025    Standard

# %%
df.isnull().sum() / len(df) * 100
# Out:
# make_model                         2.883311
# short_description                  2.883311
# make                               2.883311
# model                              2.883311
# location                           2.883311
# price                              2.883311
# body_type                          2.883311
# type                               2.883311
# doors                              4.101085
# country_version                   42.710312
# offer_number                      21.641791
# warranty                          46.458616
# mileage                            2.886703
# first_registration                 2.890095
# gearbox                            3.724559
# fuel_type                          8.945047
# colour                             8.731343
# paint                             50.831072
# desc                               4.860923
# seller                             2.883311
# seats                             13.483718
# power                              4.823609
# engine_size                        7.642469
# gears                             35.705563
# co_emissions                      36.926730
# manufacturer_colour               26.095658
# drivetrain                        42.696744
# cylinders                         36.051560
# fuel_consumption                  20.675034
# comfort_&_convenience             13.727951
# entertainment_&_media             19.796472
# safety_&_security                 13.789009
# extras                            20.352782
# empty_weight                      39.762551
# model_code                        71.618046
# general_inspection                58.432836
# last_service                      93.205563
# full_service_history              57.377883
# non_smoker_vehicle                60.671642
# emission_class                    39.419946
# emissions_sticker                 68.066486
# upholstery_colour                 50.580054
# upholstery                        36.872456
# production_date                   79.959294
# previous_owner                    52.459294
# other_fuel_types                  92.154003
# power_consumption                 98.253053
# energy_efficiency_class           73.527815
# co_efficiency                     73.527815
# fuel_consumption_wltp             99.660787
# co_emissions_wltp                 99.606513
# available_from                    98.666893
# taxi_or_rental_car                98.568521
# availability                      98.978969
# last_timing_belt_change           98.059701
# electric_range_wltp               99.945726
# power_consumption_wltp            99.945726
# battery_ownership                 99.976255
# age                                2.890095
# power_kW                           4.823609
# horse_power                        4.837178
# f_consumption_per_100_combined    21.272049
# comfort_convenience_pack          13.727951
# safety_security_pack              13.789009
# entertainment_pack                19.796472
# extra_pack                        20.352782
# dtype: float64

# %%
df.isnull().sum()
# Out:
# make_model                          850
# short_description                   850
# make                                850
# model                               850
# location                            850
# price                               850
# body_type                           850
# type                                850
# doors                              1209
# country_version                   12591
# offer_number                       6380
# warranty                          13696
# mileage                             851
# first_registration                  852
# gearbox                            1098
# fuel_type                          2637
# colour                             2574
# paint                             14985
# desc                               1433
# seller                              850
# seats                              3975
# power                              1422
# engine_size                        2253
# gears                             10526
# co_emissions                      10886
# manufacturer_colour                7693
# drivetrain                        12587
# cylinders                         10628
# fuel_consumption                   6095
# comfort_&_convenience              4047
# entertainment_&_media              5836
# safety_&_security                  4065
# extras                             6000
# empty_weight                      11722
# model_code                        21113
# general_inspection                17226
# last_service                      27477
# full_service_history              16915
# non_smoker_vehicle                17886
# emission_class                    11621
# emissions_sticker                 20066
# upholstery_colour                 14911
# upholstery                        10870
# production_date                   23572
# previous_owner                    15465
# other_fuel_types                  27167
# power_consumption                 28965
# energy_efficiency_class           21676
# co_efficiency                     21676
# fuel_consumption_wltp             29380
# co_emissions_wltp                 29364
# available_from                    29087
# taxi_or_rental_car                29058
# availability                      29179
# last_timing_belt_change           28908
# electric_range_wltp               29464
# power_consumption_wltp            29464
# battery_ownership                 29473
# age                                 852
# power_kW                           1422
# horse_power                        1426
# f_consumption_per_100_combined     6271
# comfort_convenience_pack           4047
# safety_security_pack               4065
# entertainment_pack                 5836
# extra_pack                         6000
# dtype: int64

# %%
df.drop(['offer_number', 'desc', 'fuel_consumption', 'model_code', 'last_service', 'power_consumption',
'co_efficiency', 'fuel_consumption_wltp', 'co_emissions_wltp', 'available_from', 'taxi_or_rental_car', 'availability',
'last_timing_belt_change', 'electric_range_wltp', 'battery_ownership', 'production_date', 'power_consumption_wltp', 'power'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29480 entries, 0 to 29479
# Data columns (total 48 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   make_model                      28630 non-null  object
#  1   short_description               28630 non-null  object
#  2   make                            28630 non-null  object
#  3   model                           28630 non-null  object
#  4   location                        28630 non-null  object
#  5   price                           28630 non-null  float64
#  6   body_type                       28630 non-null  object
#  7   type                            28630 non-null  object
#  8   doors                           28271 non-null  float64
#  9   country_version                 16889 non-null  object
#  10  warranty                        15784 non-null  object
#  11  mileage                         28629 non-null  float64
#  12  first_registration              28628 non-null  object
#  13  gearbox                         28382 non-null  object
#  14  fuel_type                       26843 non-null  object
#  15  colour                          26906 non-null  object
#  16  paint                           14495 non-null  object
#  17  seller                          28630 non-null  object
#  18  seats                           25505 non-null  float64
#  19  engine_size                     27227 non-null  float64
#  20  gears                           18954 non-null  float64
#  21  co_emissions                    18594 non-null  float64
#  22  manufacturer_colour             21787 non-null  object
#  23  drivetrain                      16893 non-null  object
#  24  cylinders                       18852 non-null  float64
#  25  comfort_&_convenience           25433 non-null  object
#  26  entertainment_&_media           23644 non-null  object
#  27  safety_&_security               25415 non-null  object
#  28  extras                          23480 non-null  object
#  29  empty_weight                    17758 non-null  float64
#  30  general_inspection              12254 non-null  object
#  31  full_service_history            12565 non-null  object
#  32  non_smoker_vehicle              11594 non-null  object
#  33  emission_class                  17859 non-null  object
#  34  emissions_sticker               9414 non-null   object
#  35  upholstery_colour               14569 non-null  object
#  36  upholstery                      18610 non-null  object
#  37  previous_owner                  14015 non-null  float64
#  38  other_fuel_types                2313 non-null   object
#  39  energy_efficiency_class         7804 non-null   object
#  40  age                             28628 non-null  float64
#  41  power_kW                        28058 non-null  float64
#  42  horse_power                     28054 non-null  float64
#  43  f_consumption_per_100_combined  23209 non-null  float64
#  44  comfort_convenience_pack        25433 non-null  object
#  45  safety_security_pack            25415 non-null  object
#  46  entertainment_pack              23644 non-null  object
#  47  extra_pack                      23480 non-null  object
# dtypes: float64(14), object(34)
# memory usage: 10.8+ MB

# %%
df.to_csv("auto_scout_part1.csv", index=False)
